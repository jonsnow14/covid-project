# %% [markdown]
# <a href="https://colab.research.google.com/github/jonsnow14/covid-project/blob/master/Redzones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from folium.plugins import HeatMap
# %matplotlib inline

# %%
data = pd.read_csv('ORANGEZONES.csv')
data.head()
# Out:
#         LOCATION    Zone  LATITUDE  LONGITUDE
# 0      Anantapur  Orange   14.6819    77.6006
# 1  East Godavari  Orange   17.1606    82.0555
# 2       Prakasam  Orange   15.6360    79.6078
# 3     Srikakulam  Orange   18.2970    83.8968
# 4  Visakhapatnam  Orange   17.6868    83.2185

# %%
data.dropna()
# Out:
#               LOCATION    Zone  LATITUDE  LONGITUDE
# 0            Anantapur  Orange   14.6819    77.6006
# 1        East Godavari  Orange   17.1606    82.0555
# 2             Prakasam  Orange   15.6360    79.6078
# 3           Srikakulam  Orange   18.2970    83.8968
# 4        Visakhapatnam  Orange   17.6868    83.2185
# ..                 ...     ...       ...        ...
# 321              Nadia  Orange   23.4845    88.5568
# 322  Paschim Bardhaman  Orange   23.4845    87.4133
# 323  Paschim Medinipur  Orange   23.6426    87.9062
# 324    Purba Bardhaman  Orange   22.3599    86.4189
# 325  South 24 Parganas  Orange   22.1815    88.5378
#
# [326 rows x 4 columns]

# %%
data[data.isnull()]
# Out:
#     LOCATION Zone  LATITUDE  LONGITUDE
# 0        NaN  NaN       NaN        NaN
# 1        NaN  NaN       NaN        NaN
# 2        NaN  NaN       NaN        NaN
# 3        NaN  NaN       NaN        NaN
# 4        NaN  NaN       NaN        NaN
# ..       ...  ...       ...        ...
# 321      NaN  NaN       NaN        NaN
# 322      NaN  NaN       NaN        NaN
# 323      NaN  NaN       NaN        NaN
# 324      NaN  NaN       NaN        NaN
# 325      NaN  NaN       NaN        NaN
#
# [326 rows x 4 columns]

# %%
data = data.dropna()

# %%
data.reset_index(drop=True)
# Out:
#               LOCATION    Zone  LATITUDE  LONGITUDE
# 0            Anantapur  Orange   14.6819    77.6006
# 1        East Godavari  Orange   17.1606    82.0555
# 2             Prakasam  Orange   15.6360    79.6078
# 3           Srikakulam  Orange   18.2970    83.8968
# 4        Visakhapatnam  Orange   17.6868    83.2185
# ..                 ...     ...       ...        ...
# 321              Nadia  Orange   23.4845    88.5568
# 322  Paschim Bardhaman  Orange   23.4845    87.4133
# 323  Paschim Medinipur  Orange   23.6426    87.9062
# 324    Purba Bardhaman  Orange   22.3599    86.4189
# 325  South 24 Parganas  Orange   22.1815    88.5378
#
# [326 rows x 4 columns]

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#         LOCATION    Zone  LATITUDE  LONGITUDE
# 0      Anantapur  Orange   14.6819    77.6006
# 1  East Godavari  Orange   17.1606    82.0555
# 2       Prakasam  Orange   15.6360    79.6078
# 3     Srikakulam  Orange   18.2970    83.8968
# 4  Visakhapatnam  Orange   17.6868    83.2185

# %%
orangezones = folium.Map([14.6819, 77.6006], zoom_start= 5)

# %%
orangezones
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in df.iterrows():
    folium.Marker([row['LATITUDE'], row['LONGITUDE']],
                  popup=row['LOCATION'],
                    icon=folium.Icon(folium.Icon(color='blue', icon_color='white', icon='orangezones', angle=0, prefix='glyphicon'))
                  ). add_to(orangezones)

# %%
orangezones
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
vishal.save('vishal.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-079487a019f0> in <module>()
# ----> 1 vishal.save('vishal.html')
#
# NameError: name 'vishal' is not defined

# %%
vishal

# %%
for index, row in df.iterrows():
       def HeatMap(data,
             name=None,
              min_opacity=0.5,
              max_zoom=18,
              max_val=1.0,
              radius=25,
              blur=15,
              gradient=None,
              overlay=True,
              control=True, 
              show=True).add_to(m)
# Out:
#   File "<ipython-input-88-e2a542f1409e>", line 12
#     show=True).add_to(m)
#               ^
# SyntaxError: invalid syntax

# %%
m

# %%
m.save('vishal1.html')
